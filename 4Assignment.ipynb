# %% [markdown]
# # ***PYTHON OOPS QUESTION ***

# %% [markdown]
# # ***1.What is Object-Oriented Programming (OOP)***

# %% [markdown]
# Ans= Object-Oriented Programming (OOP) is a programming paradigm that organizes software design around objects rather than functions or logic. Objects represent real-world entities and contain both data (attributes) and behavior (methods/functions). The main principles of OOP are:
#
# Encapsulation – Bundling data and methods into a single unit (class) and restricting direct access.
#
# Inheritance – Allowing one class to use properties and methods of another class.
#
# Polymorphism – Enabling the same method or function to behave differently based on the object.
#
# Abstraction – Hiding complex details and showing only the essential features.

# %% [markdown]
# # ***2. What is a class in OOP***

# %% [markdown]
# Ans= A class in OOP is a blueprint or template used to create objects. It defines the properties (attributes/variables) and behaviors (methods/functions) that the objects created from it will have. For example, a Car class may have attributes like color and model, and methods like drive() or brake(). Objects (like a red car or blue car) are specific instances of that class.

# %% [markdown]
# # ***3. What is an object in OOP***

# %% [markdown]
# Ans=An object in OOP is an instance of a class that represents a real-world entity. It contains data (attributes) and functions (methods) defined by its class. For example, if Car is a class, then a specific red BMW car is an object. Each object can have different values for its attributes but shares the same structure and behavior defined by the class.

# %% [markdown]
# # ***4. What is the difference between abstraction and encapsulation***

# %% [markdown]
# Ans=Abstraction hides the complex implementation details and shows only the essential features of an object, focusing on what the object does. Encapsulation hides the internal data and restricts direct access using access modifiers, focusing on how the data is protected.

# %% [markdown]
# # ***5.What are dunder methods in Python***

# %% [markdown]
# Ans= Dunder methods (short for “double underscore” methods) in Python are special methods that have two underscores before and after their names, like _init_ or _str. They allow you to define or customize the behavior of objects for built-in operations, such as object creation, string representation, addition, or comparison. For example, __init_ initializes an object when it’s created, and _add_ defines how two objects are added.

# %% [markdown]
# # ***6. Explain the concept of inheritance in OOP***

# %% [markdown]
# Ans=Inheritance in OOP is a mechanism where a class (called child or subclass) can acquire properties and methods from another class (called parent or superclass). It promotes code reusability and hierarchical relationships. For example, if Vehicle is a parent class with attributes like speed and capacity, a Car subclass can inherit these attributes and also have its own specific features like airbags or sunroof.

# %% [markdown]
# # ***7. What is polymorphism in OOp***

# %% [markdown]
# Ans= Polymorphism in Object-Oriented Programming (OOP) is the concept that allows a single function, method, or operator to perform different tasks depending on the object it is acting upon. In simple terms, it means “one name, many forms.” For example, the same method name can be defined in multiple classes, but each class provides its own implementation. This makes code more flexible, reusable, and easier to maintain, as the same interface can be used for different underlying forms (objects).

# %% [markdown]
# # ***8. How is encapsulation achieved in Python***

# %% [markdown]
# Ans=Encapsulation in Python is achieved by restricting direct access to an object’s attributes using access modifiers. By convention, a single underscore (var) indicates a protected attribute, while a double underscore (_var) makes it private. Access to these attributes is controlled through getter and setter methods, which allow reading or modifying the data safely without exposing the internal implementation.

# %% [markdown]
# # ***9. What is a constructor in Python+***

# %% [markdown]
# Ans=A constructor in Python is a special method called _init_() that is automatically executed when a new object of a class is created. It is used to initialize the object’s attributes with specific values and set up any necessary state for the object. For example, in a Car class, the constructor can set the color and model when creating a new car object.

# %% [markdown]
# # ***10.What are class and static methods in Python***

# %% [markdown]
# Ans= In Python, class methods are methods that take the class itself (cls) as the first parameter instead of an instance. They can access or modify class-level attributes and are defined using the @classmethod decorator.
#
# Static methods do not take self or cls and cannot access instance or class attributes. They behave like regular functions but belong to the class’s namespace and are defined using the @staticmethod decorator.

# %% [markdown]
# # ***11. What is method overloading in Python***

# %% [markdown]
# Ans=Method overloading in Python is the ability to define multiple methods with the same name but different parameters within a class. However, Python does not support traditional method overloading like other languages; the latest defined method overrides the previous ones. Overloading behavior can be achieved using default arguments or variable-length arguments (*args, **kwargs) to handle different input scenarios.

# %% [markdown]
# # ***12.What is method overriding in OOP***

# %% [markdown]
# Ans=Method overriding in OOP occurs when a subclass provides its own implementation of a method that is already defined in its parent class. This allows the subclass to modify or extend the behavior of the inherited method while keeping the same method name and parameters, enabling polymorphism. For example, a Car class can override a start() method inherited from a Vehicle class to provide car-specific behavior.

# %% [markdown]
# # ***13.What is a property decorator in Python***

# %% [markdown]
# Ans=A property decorator in Python (@property) is used to turn a method into a read-only attribute, allowing you to access it like a regular attribute instead of calling it as a method. It helps in encapsulating data while providing controlled access. You can also define a setter using @<property_name>.setter to allow updating the attribute safely.

# %% [markdown]
# # ***14. Why is polymorphism important in OOP***

# %% [markdown]
# Ans=Polymorphism is important in OOP because it allows one interface to be used for different types of objects, making code more flexible, reusable, and easier to maintain.

# %% [markdown]
# # ***15. What is an abstract class in Python***

# %% [markdown]
# Ans=In Python, an **abstract class** is a class that acts as a blueprint for other classes and cannot be instantiated directly. It is used when you want to define a common structure that other subclasses must follow, but you don’t want the base class itself to be used for creating objects. Abstract classes are defined using the `abc` (Abstract Base Class) module, and they can contain **abstract methods**, which are methods declared but not implemented in the base class. Any subclass that inherits from an abstract class is required to provide its own implementation of these abstract methods; otherwise, it too becomes abstract and cannot be instantiated. The main purpose of abstract classes is to enforce a certain structure in subclasses, promote code reusability, and ensure that essential methods are always implemented. For example, if an abstract class `Animal` has an abstract method `sound()`, then subclasses like `Dog` and `Cat` must implement the `sound()` method in their own way. This ensures consistency across all subclasses while still allowing flexibility in how they implement the required behavior.

# %% [markdown]
# # ***16.What are the advantages of OOP***

# %% [markdown]
# Ans=Here are the main **advantages of OOP (Object-Oriented Programming):**
#
# 1. **Modularity** – Code is divided into classes and objects, making it easier to organize.
# 2. **Reusability** – Classes can be reused in different programs, reducing duplication.
# 3. **Scalability** – OOP makes it easier to build and maintain large, complex systems.
# 4. **Encapsulation** – Data and methods are bundled together, improving security and reducing errors.
# 5. **Inheritance** – New classes can be built from existing ones, saving development time.
# 6. **Polymorphism** – The same interface can work with different data types or classes, increasing flexibility.
# 7. **Maintainability** – OOP code is easier to modify, debug, and extend.

# %% [markdown]
# # ***17. What is the difference between a class variable and an instance variable***

# %% [markdown]
# Ans= Here’s the difference in simple terms:
#
# **Class Variable**
#
# Shared by all objects of the class.
#
# Defined inside the class but outside any method.
#
# Changing it affects all instances (unless overridden).
#
# **Instance Variable**
#
# Belongs to a specific object.
#
# Defined inside the constructor (__init__) or methods using self.
#
# Each object gets its own copy

# %% [markdown]
# # ***18.What is multiple inheritance in Python***

# %% [markdown]
# Ans=In Python, multiple inheritance means that a class can inherit features (methods and attributes) from more than one parent class. This allows the child class to use functionality from all its parent classes, making it more powerful and flexible. For example, if one parent class handles input/output operations and another handles mathematical operations, a child class can inherit from both and use their features together. However, multiple inheritance can sometimes lead to confusion if two parent classes have methods with the same name. To resolve such conflicts, Python follows a specific order called the Method Resolution Order (MRO), which decides which parent’s method should be used first. This makes multiple inheritance useful but requires careful design to avoid complexity.

# %% [markdown]
# # ***19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python***

# %% [markdown]
# Ans=In Python, both __str__ and __repr__ are special methods used to define how objects of a class are represented as strings, but their purposes are slightly different:
#
# __str__ → Used to give a human-readable string representation of the object (meant for users). It’s what you see when you use print(object).
#
# __repr__ → Used to give an unambiguous, developer-friendly representation of the object (meant for debugging). Ideally, it should return a string that could recreate the object if passed to eval()

# %% [markdown]
# # ***20.  What is the significance of the ‘super()’ function in Python***

# %% [markdown]
# Ans= The super() function in Python is used to call a method from a parent (super) class inside a child class. Its main significance is that it allows us to reuse code from the parent class without rewriting it, and it also helps in maintaining the method resolution order (MRO), especially in cases of multiple inheritance.
#
# Key Points about super():
#
# **Code Reusability **– Calls parent methods, avoiding duplication.
#
# Method Resolution Order (MRO) – Ensures the correct method is called in multiple inheritance.
#
# **Extensibility** – Allows child classes to extend or modify parent behavior instead of fully replacing it.

# %% [markdown]
# # ***21.What is the significance of the __del__ method in Python***

# %% [markdown]
# Ans= The __del__ method in Python is known as a destructor. Its significance lies in the fact that it is automatically called when an object is about to be destroyed, either when its reference count drops to zero or when the program ends. The purpose of this method is to handle cleanup tasks such as closing files, releasing memory, or disconnecting from databases before the object is removed from memory. For example, if an object is managing a file, the __del__ method can ensure that the file is properly closed once the object is no longer needed. However, it is important to note that relying solely on __del__ is not always safe, because the exact time of object destruction is handled by Python’s garbage collector, which may delay or skip calling it in some cases. Therefore, while __del__ is useful for cleanup, developers often prefer using context managers (with statement) for more reliable resource management.

# %% [markdown]
# # ***22. What is the difference between @staticmethod and @classmethod in Python***

# %% [markdown]
# Ans= In Python, both `@staticmethod` and `@classmethod` are used to define methods inside a class that are not regular instance methods, but they serve different purposes. A `@staticmethod` is a method that does not depend on the class or its instances; it behaves just like a normal function but is placed inside a class for better organization. Since it doesn’t take the `self` or `cls` parameter, it cannot access or modify instance variables or class variables directly. On the other hand, a `@classmethod` is a method that receives the class itself as the first argument, usually named `cls`. This allows it to access and modify class-level attributes that are shared across all instances of the class. In short, a static method is used when you just need a utility function grouped inside a class, while a class method is used when you need to work with class-level data or create alternative constructors for the class.

# %% [markdown]
# # ***23. How does polymorphism work in Python with inheritance***

# %% [markdown]
# Ans= In Python, polymorphism with inheritance means that a child class can provide its own version of a method that already exists in the parent class, and when that method is called on an object, Python decides at runtime which version to execute depending on the object’s type. This is usually achieved through **method overriding**, where the child class defines a method with the same name as the parent class, but with different or extended behavior. For example, if a parent class `Animal` has a method `sound()`, and subclasses like `Dog` and `Cat` override this method to return “Woof” and “Meow” respectively, then when `sound()` is called on an `Animal` reference pointing to a `Dog` object, the dog’s version of the method is executed. This demonstrates the principle of “one interface, many implementations,” allowing the same method call to behave differently based on the object’s class. Polymorphism in inheritance makes code more flexible and extensible, since new child classes can be added without changing existing code that depends on the parent class interface.

# %% [markdown]
# # ***24. What is method chaining in Python OOP***

# %% [markdown]
# Ans= In Python OOP, **method chaining** is a technique where multiple methods are called on the same object in a single line, one after another. This works because each method returns the object itself (`self`), allowing another method to be called immediately on the returned object. For example, in a class `Person`, if the methods `setName()`, `setAge()`, and `setCity()` all return `self`, then we can write `p.setName("Alice").setAge(20).setCity("Paris")` instead of calling them separately. The main significance of method chaining is that it makes the code shorter, cleaner, and more readable by combining multiple operations into a single expression, while still maintaining object-oriented principles.

# %% [markdown]
# # ***25.What is the purpose of the __call__ method in Python***

# %% [markdown]
# Ans= In Python, the **`__call__` method** allows an object of a class to be used as if it were a function. When you define `__call__` inside a class, creating an instance of that class makes it possible to “call” the instance directly using parentheses, just like calling a normal function. The main purpose of `__call__` is to give objects function-like behavior while still keeping them as objects with state and attributes. For example, you might create a class that processes numbers and by implementing `__call__`, you can pass input to the object as though it were a function. This is useful in situations like building decorators, machine learning models, or objects that need to behave dynamically. In short, `__call__` bridges the gap between functions and objects, making objects more flexible and powerful in Python.

# %% [markdown]
# # **PRACTICAL QUESTION**

# %% [markdown]
# # ***1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".***

# %%
class Animal:
    def speak(self):
        print("This animal makes a sound.")

class Dog(Animal):
    def speak(self):
        print("Bark!")

a = Animal()
a.speak()

d = Dog()
d.speak()
# Out:
# This animal makes a sound.
# Bark!

# %% [markdown]
# # ***2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.***

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, r):
        self.r = r
    def area(self):
        return 3.14 * self.r * self.r

class Rectangle(Shape):
    def __init__(self, l, w):
        self.l = l
        self.w = w
    def area(self):
        return self.l * self.w

c = Circle(5)
r = Rectangle(4, 6)

print("Circle area:", c.area())
print("Rectangle area:", r.area())
# Out:
# Circle area: 78.5
# Rectangle area: 24

# %% [markdown]
# # ***3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.***

# %%
class Vehicle:
    def __init__(self, v_type):
        self.v_type = v_type

class Car(Vehicle):
    def __init__(self, v_type, brand):
        super().__init__(v_type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, v_type, brand, battery):
        super().__init__(v_type, brand)
        self.battery = battery

e = ElectricCar("Four Wheeler", "Tesla", "85 kWh")
print("Type:", e.v_type)
print("Brand:", e.brand)
print("Battery:", e.battery)
# Out:
# Type: Four Wheeler
# Brand: Tesla
# Battery: 85 kWh

# %% [markdown]
# # ***4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.***

# %%
class Bird:
    def fly(self):
        print("Some birds can fly.")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky!")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, they swim instead!")


birds = [Sparrow(), Penguin()]

for b in birds:
    b.fly()
# Out:
# Sparrow flies high in the sky!
# Penguins cannot fly, they swim instead!

# %% [markdown]
# # ***5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.***

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount
        print("Deposited:", amount)

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print("Withdrawn:", amount)
        else:
            print("Insufficient balance!")

    def check_balance(self):
        print("Current Balance:", self.__balance)


acc = BankAccount(1000)
acc.deposit(500)
acc.withdraw(300)
acc.check_balance()
# Out:
# Deposited: 500
# Withdrawn: 300
# Current Balance: 1200

# %% [markdown]
# # ***6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().***

# %%
class Instrument:
    def play(self):
        print("Instrument is playing a sound.")

class Guitar(Instrument):
    def play(self):
        print("Guitar is playing strings.")

class Piano(Instrument):
    def play(self):
        print("Piano is playing melody.")


instruments = [Guitar(), Piano()]

for i in instruments:
    i.play()
# Out:
# Guitar is playing strings.
# Piano is playing melody.

# %% [markdown]
# # ***7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.***

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Testing
print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %% [markdown]
# # ***8. Implement a class Person with a class method to count the total number of persons created.***

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count


p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %% [markdown]
# # ***9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".***

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


f1 = Fraction(3, 4)
f2 = Fraction(5, 8)

print(f1)
print(f2)
# Out:
# 3/4
# 5/8

# %% [markdown]
# # ***10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.***

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(4, 5)
v3 = v1 + v2

print("v1:", v1)
print("v2:", v2)
print("v1 + v2 =", v3)
# Out:
# v1: (2, 3)
# v2: (4, 5)
# v1 + v2 = (6, 8)

# %% [markdown]
# # ***11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."***

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")


p1 = Person("Alice", 20)
p1.greet()
# Out:
# Hello, my name is Alice and I am 20 years old.

# %% [markdown]
# # ***12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.***

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)


s1 = Student("Alice", [85, 90, 78])
print("Average grade of", s1.name, "=", s1.average_grade())
# Out:
# Average grade of Alice = 84.33333333333333

# %% [markdown]
# # ***13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.***

# %%
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


rect = Rectangle()
rect.set_dimensions(5, 3)
print("Area of rectangle:", rect.area())
# Out:
# Area of rectangle: 15

# %% [markdown]
# # ***14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.***

# %%
class Employee:
    def __init__(self, hours, rate):
        self.hours = hours
        self.rate = rate

    def calculate_salary(self):
        return self.hours * self.rate

class Manager(Employee):
    def __init__(self, hours, rate, bonus):
        super().__init__(hours, rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# Testing
e = Employee(40, 200)
m = Manager(40, 200, 5000)

print("Employee Salary:", e.calculate_salary())
print("Manager Salary:", m.calculate_salary())
# Out:
# Employee Salary: 8000
# Manager Salary: 13000

# %% [markdown]
# # ***15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.***

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

p1 = Product("Laptop", 50000, 2)
print("Product:", p1.name)
print("Total Price:", p1.total_price())
# Out:
# Product: Laptop
# Total Price: 100000

# %% [markdown]
# # ***16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method***

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

c = Cow()
s = Sheep()

print("Cow sound:", c.sound())
print("Sheep sound:", s.sound())
# Out:
# Cow sound: Moo
# Sheep sound: Baa

# %% [markdown]
# # ***17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.***

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"


b1 = Book("The Alchemist", "Paulo Coelho", 1988)
print(b1.get_book_info())
# Out:
# 'The Alchemist' by Paulo Coelho, published in 1988

# %% [markdown]
# # ***18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.***

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


m = Mansion("123 Luxury St", 50000000, 10)
print("Address:", m.address)
print("Price:", m.price)
print("Number of Rooms:", m.number_of_rooms)
# Out:
# Address: 123 Luxury St
# Price: 50000000
# Number of Rooms: 10
